# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# allmodels = np.load('/home/cheng/BayHunter-master/CH018/results/data/c_models.npy')
x_age, y_rsl = np.loadtxt('tutorial/results/best_mode_model.txt').T
# allmodels = allmodels[~np.isnan(allmodels)]
x_age, y_rsl, x_age[1:]-x_age[:-1]

# %%
model_last = model
segment = int(len(model_last)/2)
x_age, y_rsl = model_last[:segment], model_last[segment:]
x_age, y_rsl, x_age[1:]-x_age[:-1]
# Out:
# (array([[-476.        , -326.1383667 , -306.85922241,  -74.29889679,
#            30.93667412,  270.37161255,  418.19223022,  468.68069458,
#           575.58135986, 1107.125     , 1428.78417969, 1852.48571777,
#          1985.14794922, 1991.85949707, 2014.90161133]]),
#  array([[-4.09585619, -3.97499871, -3.78712296, -3.62074852, -3.27737498,
#          -3.15003204, -2.61949062, -2.74762487, -2.39330316, -1.61217153,
#          -1.26913369, -0.63731587, -0.21553746, -0.05990498, -0.00879575]]),
#  array([], shape=(0, 15), dtype=float64))

# %%
station = 'NJ_CC.csv'
sea_level = pd.read_csv(station)
x_obs_raw = 1950-np.array(sea_level['Age'])
y_obs_raw = np.array(sea_level['RSL'])
sort_idx = np.argsort(x_obs_raw)
x_obs = x_obs_raw[sort_idx]
y_obs = y_obs_raw[sort_idx]

y_pred = np.interp(x_obs, x_age[:-1], y_rsl[:-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [257], line 9
#       6 x_obs = x_obs_raw[sort_idx]
#       7 y_obs = y_obs_raw[sort_idx]
# ----> 9 y_pred = np.interp(x_obs, x_age[:-1], y_rsl[:-1])
#
# File <__array_function__ internals>:5, in interp(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:1439, in interp(x, xp, fp, left, right, period)
#    1436     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1437     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1439 return interp_func(x, xp, fp, left, right)
#
# ValueError: object too deep for desired array

# %%
x_obs, y_pred
# Out:
# (array([-476, -455, -401, -339, -329, -319, -314, -307, -301, -292, -264,
#         -240, -200, -124,  -87,  -53,  -40,  -19,   27,  148,  311,  335,
#          387,  404,  409,  424,  457,  470,  477,  481,  490,  498,  505,
#          514,  522,  533,  538,  551,  564,  573,  585,  604,  626,  666,
#          685,  699,  708,  720,  732,  747,  767,  787,  804,  819,  835,
#          849,  871,  907,  939,  967,  969,  994, 1009, 1010, 1024, 1029,
#         1036, 1065, 1108, 1119, 1135, 1154, 1173, 1181, 1209, 1226, 1238,
#         1248, 1255, 1286, 1294, 1318, 1323, 1420, 1463, 1509, 1521, 1532,
#         1594, 1604, 1612, 1645, 1661, 1687, 1700, 1727, 1756, 1785, 1790,
#         1803, 1829, 1861, 1864, 1867, 1873, 1877, 1882, 1887, 1894, 1904,
#         1907, 1911, 1912, 1915, 1925, 1934, 1941, 1947, 1954, 1959, 1962,
#         1965, 1967, 1969, 1971, 1975, 1978, 1983, 1986, 1987, 1988, 1989,
#         1991, 1993, 1995, 2017]),
#  array([-4.10935354, -4.10443119, -4.09177372, -4.01292691, -3.95600653,
#         -3.89908615, -3.87062596, -3.83078169, -3.79662946, -3.78354353,
#         -3.76541929, -3.74988423, -3.72399245, -3.67479809, -3.6508482 ,
#         -3.57899538, -3.5239906 , -3.43513672, -3.24050441, -3.19992061,
#         -2.9875181 , -2.89865654, -2.70612317, -2.64317957, -2.62466675,
#         -2.64507449, -2.72035452, -2.72030192, -2.69972882, -2.68797276,
#         -2.66152162, -2.6380095 , -2.6174364 , -2.59098526, -2.56747314,
#         -2.53514398, -2.5204489 , -2.4822417 , -2.44403451, -2.41758337,
#         -2.39637088, -2.36729518, -2.33362859, -2.2724166 , -2.2433409 ,
#         -2.2219167 , -2.20814401, -2.18978041, -2.17141681, -2.14846231,
#         -2.11785632, -2.08725032, -2.06123523, -2.03828073, -2.01379593,
#         -1.99237174, -1.95870514, -1.90361435, -1.85464476, -1.81179636,
#         -1.80873577, -1.77047827, -1.74752377, -1.74599347, -1.72456928,
#         -1.71691778, -1.70620568, -1.66182699, -1.5960241 , -1.58022643,
#         -1.56403981, -1.54481819, -1.52559658, -1.51750327, -1.48917669,
#         -1.47197841, -1.45983844, -1.4497218 , -1.44264016, -1.41127858,
#         -1.40318527, -1.37890534, -1.37384702, -1.27203651, -1.20911374,
#         -1.14180102, -1.12424118, -1.10814466, -1.01741881, -1.00278561,
#         -0.99107905, -0.94278949, -0.91937637, -0.88133005, -0.86230689,
#         -0.82279724, -0.78036096, -0.73792468, -0.73060808, -0.71158492,
#         -0.6735386 , -0.58663323, -0.57760396, -0.5685747 , -0.55051617,
#         -0.53847715, -0.52342838, -0.5083796 , -0.48731132, -0.45721377,
#         -0.44818451, -0.43614549, -0.43313573, -0.42410647, -0.39400892,
#         -0.36692113, -0.34585284, -0.32779432, -0.30672603, -0.29167726,
#         -0.28264799, -0.27361873, -0.26759922, -0.26157971, -0.2555602 ,
#         -0.24352118, -0.23449192, -0.21944314, -0.21041388, -0.20570971,
#         -0.16909075, -0.13247179, -0.0628144 , -0.0628144 , -0.0628144 ,
#         -0.0628144 ]))

# %%
plt.plot(x_obs, y_obs)
plt.plot(x_obs, y_pred)

# %%
plt.plot(x_obs[1:], (y_pred[1:]-y_pred[:-1])/(x_obs[1:]-x_obs[:-1])*1000)

# %%
plt.plot(x_obs, y_obs-y_pred, '*')

# %%
np.mean(np.abs(y_obs-y_pred))
# Out:
# 0.02263195057594678
